# %%
from import_tracker import yada

path = "/home/zes5027/GIT/fitpack"
imports = yada(path)
# Out:
# /home/zes5027/GIT/fitpack/tools/__init__.py
# /home/zes5027/GIT/fitpack/tools/config.py
# /home/zes5027/GIT/fitpack/tools/bar.py
#     sys
#     os
# /home/zes5027/GIT/fitpack/examples/upol-soft.py
# /home/zes5027/GIT/fitpack/obslib/AN_pp/AN_theory_051818.py
#     sys
#     os
#     numpy
#     pandas
#     math
#     time
#     tools.tools: load_config
#     external.CJLIB.CJ: CJ
#     external.LSSLIB.LSS: LSS
#     external.DSSLIB.DSS: DSS
#     qcdlib.tmdlib: PDF, PPDF, FF
#     qcdlib.tmdlib: TRANSVERSITY
#     qcdlib.tmdlib: COLLINS
#     qcdlib.aux: AUX
#     tools.config: conf
#     scipy.integrate: quad, dblquad, fixed_quad
# /home/zes5027/GIT/fitpack/obslib/sidis/reader.py
#     sys
#     os
#     numpy
#     pandas
#     tools.reader: _READER
#     tools.config: conf
# /home/zes5027/GIT/fitpack/fitlab/maxlike.py
#     sys
#     os
#     time
#     copy
#     numpy
#     tools.tools: load, save, checkdir, load_config
#     scipy.optimize: leastsq, minimize
# ...
