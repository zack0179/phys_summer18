# %%
from import_tracker import yada

path = "/home/zes5027/GIT/fitpack"
imports = yada(path)
# Out:
# /home/zes5027/GIT/fitpack/tools/__init__.py
# /home/zes5027/GIT/fitpack/tools/config.py
# /home/zes5027/GIT/fitpack/tools/bar.py
#     sys
#     os
# /home/zes5027/GIT/fitpack/examples/upol-soft.py
# /home/zes5027/GIT/fitpack/obslib/AN_pp/AN_theory_051818.py
#     sys
#     os
#     numpy
#     pandas
#     math
#     time
#     tools.tools
#         edge: load_config
#     external.CJLIB.CJ
#         edge: CJ
#     external.LSSLIB.LSS
#         edge: LSS
#     external.DSSLIB.DSS
#         edge: DSS
#     qcdlib.tmdlib
#         edge: PDF, PPDF, FF
#     qcdlib.tmdlib
#         edge: TRANSVERSITY
#     qcdlib.tmdlib
#         edge: COLLINS
#     qcdlib.aux
#         edge: AUX
#     tools.config
#         edge: conf
#     scipy.integrate
#         edge: quad, dblquad, fixed_quad
# /home/zes5027/GIT/fitpack/obslib/sidis/reader.py
#     sys
#     os
#     numpy
#     pandas
#     tools.reader
#         edge: _READER
#     tools.config
#         edge: conf
# ...
